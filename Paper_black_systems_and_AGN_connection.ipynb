# %%
import sys

sys.path.append('/home/aklantbhowmick/anaconda3/lib/python3.7/site-packages')
sys.path.append('/home/aklantbhowmick/anaconda3/lib/python3.7/site-packages/scalpy/')
sys.path.append('/home/aklantbhowmick/anaconda3/envs/nbodykit-env/lib/python3.6/site-packages/')
import mdot_to_Lbol
import arepo_package
import scipy.interpolate
radiative_efficiency=0.1
total_conv=mdot_to_Lbol.get_conversion_factor_arepo(radiative_efficiency)

import h5py

import operator as op
from functools import reduce

def ncr(n, r):
    r = min(r, n-r)
    numer = reduce(op.mul, range(n, n-r, -1), 1)
    denom = reduce(op.mul, range(1, r+1), 1)
    return numer / denom
# %pylab inline

# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib
# Populating the interactive namespace from numpy and matplotlib

# %%
log_LINKING_LENGTH_space=numpy.linspace(-2,2,40)
log_bhmass_cuts_space=[6]

scale_of_interest_space=numpy.array([1.0,0.1,0.015])

f,ax=plt.subplots(len(scale_of_interest_space),len(redshift_space),figsize=(20,14),sharey=True,sharex=True)

N_space=numpy.arange(1,50)

cols=['blue','red','green','cyan']
skip=3

redshift=1
save_output_path='/ufrc/lblecha/aklantbhowmick/richness_output_AGN_activity/'


ii=0

RR_active_interest=1

#log_lum_cut_space=[42.0]


log_bhmass_cut=6.0

log_lum_cut=43

scale_of_interest=1.0

ii=0
run='L75n1820TNG'
redshift_space=[0.0,2,4]

for scale_of_interest in scale_of_interest_space:
    jj=0
    #run='L75n1820TNG'
    #if (ii==2):
    #    run='L35n2160TNG'
    for redshift in redshift_space:  
        #print(log_scale_of_interest)
        obj=ax[ii,jj]
        obj2=ax[ii,jj]
        if(1==1):
            ax[0,jj].set_title('$z=%d$'%redshift,fontsize=35)
 
        
        
        

        
            obj.tick_params(labelsize=30)
            obj2.tick_params(labelsize=30)


            log_scale_of_interest=log_LINKING_LENGTH_space[log_LINKING_LENGTH_space<numpy.log10(scale_of_interest)][-1]  
        #scale_of_interest=0.5
            #obj=ax[0,jj]
            #run='L205n2500TNG'
            
                   
            obj.text(0.5,0.9,'$d_{\mathrm{max}}=%.2f\ \mathrm{Mpc}/h$'%scale_of_interest,horizontalalignment='center',verticalalignment='center', transform=obj.transAxes,fontsize=20)
 
            NBINS=7
            colormap='YlGnBu'
            opacity=1
            RICHNESS,RICHNESS_active_42,RICHNESS_active_43,RICHNESS_active_44,RICHNESS_active_45,RICHNESS_active_46,RICHNESS_active_47,RICHNESS_BH_70,RICHNESS_BH_80,RICHNESS_BH_90,RICHNESS_BH_100,primary_tag,primary_half_by_halomass,primary_half_by_bhmass,BH_Mass_primary,bolometric_luminosity_primary,host_halo_mass_primary=numpy.load(save_output_path+run+'log_bhmass_cut_%.1f_redshift_%.2f_log_LINKING_LENGTH_%.2f_all_info_more_bound.npy'%(log_bhmass_cut,redshift,log_scale_of_interest))

                
            mask=bolometric_luminosity_primary>0
            obj.errorbar(numpy.log10(host_halo_mass_primary[mask]),RICHNESS[mask],color='black',linestyle=' ',alpha=0.3,ms=10,marker='o',label='All systems') 
            
            mask=bolometric_luminosity_primary>1e44
            #obj.errorbar(numpy.log10(host_halo_mass_primary[mask]),RICHNESS[mask],color='red',linestyle=' ',alpha=0.5,ms=10,marker='o',label='$\log_{10}L_{primary}[ergs/sec]>44$') 
          
            
            #pickle.dump([N_space,number/BOXSIZE**3,poisson_error/BOXSIZE**3],open('./output_multiplicity_functions/multiplicity_functions_log_bhmass_cut_%.1f_redshift_%.2f_log_LINKING_LENGTH_%.2f.pickle'%(log_bhmass_cut,redshift,log_scale_of_interest),'w'))
        x_labl='$\log_{10}M_h[M_{\odot}/h]$'
        obj.set_xlabel(x_labl,fontsize=30)
        obj.set_yscale('log')
        obj.set_ylim(0.8,100)
        obj.set_xlim(9.5,14.7)
        jj+=1
        yticks=numpy.array([0,1,2,4,10,20])
        obj.set_yticks(yticks)
        obj.set_yticklabels(yticks.astype(str))
            
    y_labl='RICHNESS'
    ax[0,0].set_ylabel(y_labl,fontsize=30)
    ax[1,0].set_ylabel(y_labl,fontsize=30)
    ax[2,0].set_ylabel(y_labl,fontsize=30)
     


    ii+=1


#obj.set_yticks([1e-6,1e-4,1e-2])

#ax[2,0].legend(loc='lower left',fontsize=15)
ax[2,2].legend(loc='lower left',fontsize=15)
plt.subplots_adjust(wspace=0,hspace=0)
#plt.savefig('./BH_multiplicity_functions_redshift_evolution.pdf',bbox_inches='tight')
            
plt.subplots_adjust(wspace=0,hspace=0)
plt.savefig('./figures_for_paper1/RICHNESS_vs_halomass_%s.png'%run,bbox_inches='tight')

# %%
redshift_space=[0.06,2,4]
log_LINKING_LENGTH_space=numpy.linspace(-2,2,40)
log_bhmass_cuts_space=[6]

scale_of_interest_space=numpy.array([1.0,0.1,0.015])

f,ax=plt.subplots(len(scale_of_interest_space),len(redshift_space),figsize=(20,14),sharey=True,sharex=True)

N_space=numpy.arange(1,50)

cols=['blue','red','green','cyan']
skip=3

redshift=1
save_output_path='/ufrc/lblecha/aklantbhowmick/richness_output_AGN_activity/'


ii=0

RR_active_interest=1

#log_lum_cut_space=[42.0]


log_bhmass_cut=6.0

log_lum_cut=43

scale_of_interest=1.0

ii=0
run='MBII'
redshift_space=[0.06,2,4]

for scale_of_interest in scale_of_interest_space:
    jj=0
    #run='L75n1820TNG'
    #if (ii==2):
    #    run='L35n2160TNG'
    for redshift in redshift_space:  
        #print(log_scale_of_interest)
        obj=ax[ii,jj]
        obj2=ax[ii,jj]
        if(1==1):
            ax[0,jj].set_title('$z=%d$'%redshift,fontsize=35)
 
        
        
        

        
            obj.tick_params(labelsize=30)
            obj2.tick_params(labelsize=30)


            log_scale_of_interest=log_LINKING_LENGTH_space[log_LINKING_LENGTH_space<numpy.log10(scale_of_interest)][-1]  
        #scale_of_interest=0.5
            #obj=ax[0,jj]
            #run='L205n2500TNG'
            
                   
            obj.text(0.5,0.9,'$d_{\mathrm{max}}=%.2f\ \mathrm{Mpc}/h$'%scale_of_interest,horizontalalignment='center',verticalalignment='center', transform=obj.transAxes,fontsize=20)
 
            NBINS=7
            colormap='YlGnBu'
            opacity=1
            RICHNESS,RICHNESS_active_42,RICHNESS_active_43,RICHNESS_active_44,RICHNESS_active_45,RICHNESS_active_46,RICHNESS_active_47,RICHNESS_BH_70,RICHNESS_BH_80,RICHNESS_BH_90,RICHNESS_BH_100,primary_tag,primary_half_by_halomass,primary_half_by_bhmass,BH_Mass_primary,bolometric_luminosity_primary,host_halo_mass_primary=numpy.load(save_output_path+run+'log_bhmass_cut_%.1f_redshift_%.2f_log_LINKING_LENGTH_%.2f_all_info_more_bound.npy'%(log_bhmass_cut,redshift,log_scale_of_interest))

                
            mask=bolometric_luminosity_primary>0
            obj.errorbar(numpy.log10(host_halo_mass_primary[mask]),RICHNESS[mask],color='black',linestyle=' ',alpha=0.3,ms=10,marker='o',label='All systems') 
            
            mask=bolometric_luminosity_primary>1e44
            #obj.errorbar(numpy.log10(host_halo_mass_primary[mask]),RICHNESS[mask],color='red',linestyle=' ',alpha=0.5,ms=10,marker='o',label='$\log_{10}L_{primary}[ergs/sec]>44$') 
          
            
            #pickle.dump([N_space,number/BOXSIZE**3,poisson_error/BOXSIZE**3],open('./output_multiplicity_functions/multiplicity_functions_log_bhmass_cut_%.1f_redshift_%.2f_log_LINKING_LENGTH_%.2f.pickle'%(log_bhmass_cut,redshift,log_scale_of_interest),'w'))
        x_labl='$\log_{10}M_h[M_{\odot}/h]$'
        obj.set_xlabel(x_labl,fontsize=30)
        obj.set_yscale('log')
        obj.set_ylim(0.8,100)
        obj.set_xlim(9.5,14.7)
        jj+=1
        yticks=numpy.array([0,1,2,4,10,20])
        obj.set_yticks(yticks)
        obj.set_yticklabels(yticks.astype(str))
            
    y_labl='RICHNESS'
    ax[0,0].set_ylabel(y_labl,fontsize=30)
    ax[1,0].set_ylabel(y_labl,fontsize=30)
    ax[2,0].set_ylabel(y_labl,fontsize=30)
     


    ii+=1


#obj.set_yticks([1e-6,1e-4,1e-2])

#ax[2,0].legend(loc='lower left',fontsize=15)
ax[2,2].legend(loc='lower left',fontsize=15)
plt.subplots_adjust(wspace=0,hspace=0)
#plt.savefig('./BH_multiplicity_functions_redshift_evolution.pdf',bbox_inches='tight')
            
plt.subplots_adjust(wspace=0,hspace=0)
plt.savefig('./figures_for_paper1/RICHNESS_vs_halomass_%s.png'%run,bbox_inches='tight')

# %%
def make_plot(run,boxsize,col,style):
    ii=0
    for redshift,co in zip(redshift_space,cols):    
        jj=0
        for scale_of_interest in scale_of_interest_space:

            obj=ax[0,jj]
            if (jj>0):
                obj.tick_params(labelleft=False)
            
            if (ii==0):
                obj.set_title('$d_{\mathrm{max}}=%.2f\ \mathrm{Mpc}/h$'%scale_of_interest,fontsize=35)

            #obj.text(0.5,0.9,'$z=%d$'%(redshift),horizontalalignment='center',verticalalignment='center', transform=obj.transAxes,fontsize=20)
            labl='z=%.2f'%redshift
 
            obj.tick_params(labelsize=40)

            obj.set_xscale('log')
            obj.set_yscale('log')
            if (1==1):
                obj.set_xlabel('$RICHNESS$',fontsize=30)
                ticks=numpy.array([1,2,4,10,100])
                obj.set_xticks(ticks)
                obj.set_xticklabels(ticks.astype(str))

                #obj.set_yticks(ticks)
                #obj.set_yticklabels(ticks.astype(str))       



                log_scale_of_interest=log_LINKING_LENGTH_space[log_LINKING_LENGTH_space<numpy.log10(scale_of_interest)][-1]  
            #scale_of_interest=0.5
                #RICHNESS,RICHNESS_active,average_log_bolometric_luminosity,average_log_BH_Mass=numpy.load(save_output_path+run+'log_bhmass_cut_%.1f_redshift_%.2f_log_LINKING_LENGTH_%.2f_log_lum_cut_%.1f.npy'%(log_bhmass_cut,redshift,log_scale_of_interest,log_lum_cut))
                RICHNESS,RICHNESS_active_42,RICHNESS_active_43,RICHNESS_active_44,RICHNESS_active_45,RICHNESS_active_46,RICHNESS_active_47,RICHNESS_BH_70,RICHNESS_BH_80,RICHNESS_BH_90,RICHNESS_BH_100,primary_tag,primary_half_by_halomass,primary_half_by_bhmass,primary_half_by_stellarmass,BH_Mass_primary,bolometric_luminosity_primary,host_halo_mass_primary,host_subhalo_SM_primary=numpy.load(save_output_path+run+'log_bhmass_cut_%.1f_redshift_%.2f_log_LINKING_LENGTH_%.2f_all_info_more_bound_median.npy'%(log_bhmass_cut,redshift,log_scale_of_interest))
                #N_space=numpy.arange(0,20)
                fraction_space=[]
                d_fraction_space=[]
                for RR in N_space:
                    extract_system=RICHNESS==RR
                    #exec("RICHNESS_active_selected=RICHNESS_active_%d[extract_system]"%log_lum_cut)
                    fraction=float(len(RICHNESS[extract_system]))#/(len(RICHNESS_active_selected)+0.0000001)    
                    fraction_space.append(fraction)  

                    d_fraction=numpy.sqrt(float(len(RICHNESS[extract_system])))#/(len(RICHNESS_active_selected)+0.0000001)    
                    d_fraction_space.append(d_fraction) 

                fraction_space=numpy.array(fraction_space)
                d_fraction_space=numpy.array(d_fraction_space)
                mask=(fraction_space>0)#&(d_fraction_space<0.5)
                obj.errorbar(N_space[mask],fraction_space[mask]/boxsize**3,d_fraction_space[mask]/boxsize**3,color=co,linewidth=2,label=labl,marker=' ',linestyle=style) 

                #pickle.dump([N_space,number/BOXSIZE**3,poisson_error/BOXSIZE**3],open('./output_multiplicity_functions/multiplicity_functions_log_bhmass_cut_%.1f_redshift_%.2f_log_LINKING_LENGTH_%.2f.pickle'%(log_bhmass_cut,redshift,log_scale_of_interest),'w'))
                obj.set_ylim(2e-6,2e0)
                ax[ii,0].set_ylabel('$n^{\mathrm{group}}$ ($h^3 Mpc^{-3}$)',fontsize=30)

                jj+=1
        ii+=1
        
        
        
def make_plot2(row,y_min,y_max):
    ii=0
    #log_lum_cut=44.0
    for log_bhmass_cut in [log_bhmass_cut2]:
        jj=0
        for scale_of_interest in scale_of_interest_space:  
            #print(log_scale_of_interest)
            obj=ax[row,jj]
            #if (ii==0):
            #    obj.set_title('$z=%d$'%(redshift),fontsize=35)

            #obj.text(0.5,0.9,'$\log_{10}{M_{bh}}[M_{\odot}/h]>%.1f$'%(log_bhmass_cut),horizontalalignment='center',verticalalignment='center', transform=obj.transAxes,fontsize=20)
            



            obj.tick_params(labelsize=30)
            #if (ii==len(log_bhmass_cuts_space)-1):


            #obj.set_xlim(10**-2.5,10**2.5)
            obj.set_ylim(y_min,y_max)
            obj.set_xscale('log')
            obj.set_yscale('log')
            if (1==1):
                obj.set_xlabel('$RICHNESS$',fontsize=30)
                ticks=numpy.array([1,2,3,4,10])
                obj.set_xticks(ticks)
                obj.set_xticklabels(ticks.astype(str))

                #obj.set_yticks(ticks)
                #obj.set_yticklabels(ticks.astype(str))       


            for redshift,col in zip(redshift_space,cols):
                
                hf = h5py.File(load_output_path_snap+run+'bh_lum_host_halo_with_id_and_mass_z%.2f_and_sub_halo_id_added_velocity_all_BHs'%(redshift))

                L_bol=hf.get('L_bol')[:]
                bhmass=hf.get('mass')[:]

                N_total=len(L_bol[bhmass>10**log_bhmass_cut])
                N_selected=len(L_bol[(bhmass>10**log_bhmass_cut)&(L_bol>10**log_lum_cut)]) 
                log_scale_of_interest=log_LINKING_LENGTH_space[log_LINKING_LENGTH_space<numpy.log10(scale_of_interest)][-1]  
            #scale_of_interest=0.5
                RICHNESS,RICHNESS_active_42,RICHNESS_active_43,RICHNESS_active_44,RICHNESS_active_45,RICHNESS_active_46,RICHNESS_active_47,RICHNESS_BH_70,RICHNESS_BH_80,RICHNESS_BH_90,RICHNESS_BH_100,primary_tag,primary_half_by_halomass,primary_half_by_bhmass,primary_half_by_stellarmass,BH_Mass_primary,bolometric_luminosity_primary,host_halo_mass_primary,host_subhalo_SM_primary=numpy.load(save_output_path+run+'log_bhmass_cut_%.1f_redshift_%.2f_log_LINKING_LENGTH_%.2f_all_info_more_bound_median.npy'%(log_bhmass_cut,redshift,log_scale_of_interest))

                #N_space=numpy.arange(1,20)
                fraction_space=[]
                fraction_random_space=[]
                d_fraction_space=[]

                if (log_lum_cut==44):
                    RICHNESS_active=RICHNESS_active_44
                if (log_lum_cut==43):
                    RICHNESS_active=RICHNESS_active_43
                if (log_lum_cut==45):
                    RICHNESS_active=RICHNESS_active_45
                if (log_lum_cut==46):
                    RICHNESS_active=RICHNESS_active_46
                if (log_lum_cut==47):
                    RICHNESS_active=RICHNESS_active_47



                for RR in N_space:
                    extract_system=RICHNESS>=RR
                    RICHNESS_active_selected=RICHNESS_active[extract_system]
                    fraction=float(len(RICHNESS_active_selected[RICHNESS_active_selected>0]))/(len(RICHNESS_active_selected)+0.0000001)    
                    fraction_space.append(fraction)  

                    d_fraction=numpy.sqrt(float(len(RICHNESS_active_selected[RICHNESS_active_selected>0])))/(len(RICHNESS_active_selected)+0.0000001)    
                    d_fraction_space.append(d_fraction) 

                    fraction_random_space.append((ncr(N_total,RR)-ncr(N_total-N_selected,RR))/ncr(N_total,RR))

                fraction_space=numpy.array(fraction_space)
                d_fraction_space=numpy.array(d_fraction_space)
                fraction_random_space=numpy.array(fraction_random_space)
                mask=(fraction_space>0)&(d_fraction_space<0.5)
                obj.errorbar(N_space[mask],fraction_space[mask],d_fraction_space[mask],color=col,linewidth=2,label='$d_{\mathrm{max}}=%.2f\ \mathrm{Mpc}/h$'%scale_of_interest,marker=' ',linestyle='-') 
                if (fraction_space[1]>0):
                    mask=fraction_random_space>0
                    norm=fraction_space[0]/fraction_random_space[0]
                    
                    
                    obj.errorbar(N_space[mask],fraction_random_space[mask]*norm,color=col,linewidth=2,marker=' ',linestyle='dashed') 
                obj.set_xlim(0.8,20)
                #pickle.dump([N_space,number/BOXSIZE**3,poisson_error/BOXSIZE**3],open('./output_multiplicity_functions/multiplicity_functions_log_bhmass_cut_%.1f_redshift_%.2f_log_LINKING_LENGTH_%.2f.pickle'%(log_bhmass_cut,redshift,log_scale_of_interest),'w'))
            

            if (jj>0):
                obj.tick_params(labelleft=False)       
            ax[row,0].set_ylabel('$f_{\mathrm{AGN}} (\log L>%.1f)$'%log_lum_cut,fontsize=30)
            jj+=1
            
            
            

 

    ii+=1


log_LINKING_LENGTH_space=numpy.linspace(-2,2,40)
log_bhmass_cut2=6
scale_of_interest_space=numpy.array([1.0,0.1,0.015])
redshift_space=[0.0,1.5,3,4]
N_space=numpy.arange(1,20)
cols=['blue','red','green','cyan']
skip=3

run='L75n1820TNG'
simulation='Illustris_TNG'
boxsize=75.

save_output_path='/ufrc/lblecha/aklantbhowmick/richness_output_AGN_activity/'
load_output_path_snap='/ufrc/lblecha/aklantbhowmick/%s_BHs/'%simulation

f,ax=plt.subplots(4,3,figsize=(20,20),sharey=False,sharex=True)
make_plot(run,boxsize,'black','solid')
ax[0,0].legend(fontsize=22,loc='upper right')

log_lum_cut=45.0
make_plot2(1,3e-4,1.2)

log_lum_cut=44.0
make_plot2(2,7e-3,1.2)

log_lum_cut=43.0
make_plot2(3,7e-2,1.2)






plt.subplots_adjust(wspace=0,hspace=0)
#plt.savefig('./BH_multiplicity_functions_redshift_evolution.pdf',bbox_inches='tight')
            
plt.savefig('./figures_for_paper1/black_hole_multiplicity_functions_%s.png'%run,bbox_inches='tight')



run='MBII'
simulation='MBII'
boxsize=100.

redshift_space=[0.06,1.5,3,4]

save_output_path='/ufrc/lblecha/aklantbhowmick/richness_output_AGN_activity/'
load_output_path_snap='/ufrc/lblecha/aklantbhowmick/%s_BHs/'%simulation

f,ax=plt.subplots(4,3,figsize=(20,20),sharey=False,sharex=True)
make_plot(run,boxsize,'black','solid')
ax[0,0].legend(fontsize=22,loc='upper right')

log_lum_cut=45.0
make_plot2(1,3e-4,1.2)

log_lum_cut=44.0
make_plot2(2,1e-3,1.2)

log_lum_cut=43.0
make_plot2(3,2e-2,1.2)






plt.subplots_adjust(wspace=0,hspace=0)
#plt.savefig('./BH_multiplicity_functions_redshift_evolution.pdf',bbox_inches='tight')
            
plt.savefig('./figures_for_paper1/black_hole_multiplicity_functions_%s.png'%run,bbox_inches='tight')

# %%
def make_plot(run,desired_scale,ls,lower_lim,upper_lim,obj,split_by_eddington=False,median=False):
    redshift_space=numpy.array([0.0,0.6,1,1.5,2,2.5,3,3.5,4])
    if (run=='MBII'):
        redshift_space=numpy.array([0.06,0.6,1,1.5,2,2.5,3,3.5,4])
        
    
    log_LINKING_LENGTH_space=numpy.linspace(-2,2,40)
    scale_of_interest_space=numpy.array([1.0,0.1,0.015])
    N_space=numpy.arange(1,50)
    cols=['blue','red','green','cyan']
    skip=3
    redshift=1
    save_output_path='/ufrc/lblecha/aklantbhowmick/richness_output_AGN_activity/'

    RR_active_interest=1


    ii=0

    for scale_of_interest in [desired_scale]:

        jj=0
        
        #if (ii==2):
        #run='L75n1820TNG'
        
        for log_lum_cut,col in zip(log_lum_cut_space,col_space):
            #print(log_scale_of_interest)
            #obj=ax[0,jj]
            #obj2=ax[1,jj]
            #if (ii==0):
            #    obj.set_title('$\log_{10}M_{bh}[M_{\odot}/h]>%.2f$'%log_bhmass_cut,fontsize=25)

            #obj.tick_params(labelsize=30)            
            #obj2.tick_params(labelsize=30)



            if (1==1):
                obj.set_xlabel('Redshift',fontsize=25)           #    obj2.set_xlabel('$RICHNESS$',fontsize=30

                log_scale_of_interest=log_LINKING_LENGTH_space[log_LINKING_LENGTH_space<numpy.log10(scale_of_interest)][-1]  
                #obj.text(0.5,0.9,'$\log_{10}M_{bh}[M_{\odot}/h]>%.2f$'%log_bhmass_cut,horizontalalignment='center',verticalalignment='center', transform=obj.transAxes,fontsize=20)  
                fraction_upper_space=[]
                d_fraction_upper_space=[] 
                fraction_lower_space=[]
                d_fraction_lower_space=[]

                for redshift in redshift_space:
                    if (median==True):
                        #print('Using medians')
                        if (split_by_eddington==False):
                            RICHNESS,RICHNESS_active_42,RICHNESS_active_43,RICHNESS_active_44,RICHNESS_active_45,RICHNESS_active_46,RICHNESS_active_47,RICHNESS_BH_70,RICHNESS_BH_80,RICHNESS_BH_90,RICHNESS_BH_100,primary_tag,primary_half_by_halomass,primary_half_by_bhmass,BH_Mass_primary,bolometric_luminosity_primary,host_halo_mass_primary=numpy.load(save_output_path+run+'log_bhmass_cut_%.1f_redshift_%.2f_log_LINKING_LENGTH_%.2f_all_info_more_bound_median.npy'%(log_bhmass_cut,redshift,log_scale_of_interest))
                        if (split_by_eddington==True):
                            RICHNESS,RICHNESS_active_42,RICHNESS_active_43,RICHNESS_active_44,RICHNESS_active_45,RICHNESS_active_46,RICHNESS_active_47,RICHNESS_BH_70,RICHNESS_BH_80,RICHNESS_BH_90,RICHNESS_BH_100,primary_tag,primary_half_by_halomass,primary_half_by_bhmass,primary_half_by_stellarmass,BH_Mass_primary,bolometric_luminosity_primary,host_halo_mass_primary,host_subhalo_SM_primary=numpy.load(save_output_path+run+'log_bhmass_cut_%.1f_redshift_%.2f_log_LINKING_LENGTH_%.2f_all_info_more_split_by_Ledd_bound_median.npy'%(log_bhmass_cut,redshift,log_scale_of_interest))

                    else:
                        if (split_by_eddington==False):
                            RICHNESS,RICHNESS_active_42,RICHNESS_active_43,RICHNESS_active_44,RICHNESS_active_45,RICHNESS_active_46,RICHNESS_active_47,RICHNESS_BH_70,RICHNESS_BH_80,RICHNESS_BH_90,RICHNESS_BH_100,primary_tag,primary_half_by_halomass,primary_half_by_bhmass,BH_Mass_primary,bolometric_luminosity_primary,host_halo_mass_primary=numpy.load(save_output_path+run+'log_bhmass_cut_%.1f_redshift_%.2f_log_LINKING_LENGTH_%.2f_all_info_more_bound.npy'%(log_bhmass_cut,redshift,log_scale_of_interest))
                        if (split_by_eddington==True):
                            RICHNESS,RICHNESS_active_42,RICHNESS_active_43,RICHNESS_active_44,RICHNESS_active_45,RICHNESS_active_46,RICHNESS_active_47,RICHNESS_BH_70,RICHNESS_BH_80,RICHNESS_BH_90,RICHNESS_BH_100,primary_tag,primary_half_by_halomass,primary_half_by_bhmass,BH_Mass_primary,bolometric_luminosity_primary,host_halo_mass_primary=numpy.load(save_output_path+run+'log_bhmass_cut_%.1f_redshift_%.2f_log_LINKING_LENGTH_%.2f_all_info_more_split_by_Ledd_bound.npy'%(log_bhmass_cut,redshift,log_scale_of_interest))
                       
                    mask_halo=host_halo_mass_primary>10**log_halo_mass_cut
                    if (log_lum_cut==44):
                        RICHNESS_active=RICHNESS_active_44
                    if (log_lum_cut==43):
                        RICHNESS_active=RICHNESS_active_43
                    if (log_lum_cut==42):
                        RICHNESS_active=RICHNESS_active_42
                    if (log_lum_cut==45):
                        RICHNESS_active=RICHNESS_active_45
                    if (log_lum_cut==46):
                        RICHNESS_active=RICHNESS_active_46
                    if (log_lum_cut==47):
                        RICHNESS_active=RICHNESS_active_47                    
                    
                    
                    extract_upper_system=((RICHNESS>=RR_active_interest)&(RICHNESS_active>=1))&mask_halo
             
                    RICHNESS_selected=RICHNESS[extract_upper_system]          
                    fraction=float(len(RICHNESS_selected[RICHNESS_selected>=RR]))/(len(RICHNESS_selected)+0.0000001)    
                    fraction_upper_space.append(fraction)  
                    d_fraction=numpy.sqrt(float(len(RICHNESS_selected[RICHNESS_selected>=RR])))/(len(RICHNESS_selected)+0.0000001)    
                    d_fraction_upper_space.append(d_fraction) 



                fraction_upper_space=numpy.array(fraction_upper_space)
                d_fraction_upper_space=numpy.array(d_fraction_upper_space)


                mask_upper=(fraction_upper_space>0)&(d_fraction_upper_space<0.5)

                labl=run 
                obj.errorbar(redshift_space[mask_upper],fraction_upper_space[mask_upper],d_fraction_upper_space[mask_upper],color=col,linewidth=2,label=labl,marker=' ',linestyle='solid')                 
                obj.set_yscale('log')
                obj.set_ylim(lower_lim,upper_lim)

                obj.set_xlabel('Redshift',fontsize=30)

                
            jj+=1
        #ax.set_ylabel('fraction',fontsize=30)
        #ax[1,0].set_ylabel('$\log_{10}{Upper half}-\log_{10}lower half$',fontsize=30)
        ii+=1

# %%
f,ax=plt.subplots(3,3,figsize=(10,8))


ls='solid'

col_space=['blue','red','green','cyan']
log_lum_cut_space=[42,43,44,45]

lower_lim=5e-4

upper_lim=3
log_halo_mass_cut=10.
log_bhmass_cut=6.0


run='L75n1820TNG'
RR=2
ii=0
for RR in [2,3,4]:
    jj=0
    for desired_scale in [1.0,0.1,0.015]:
        obj=ax[ii,jj]
        make_plot(run,desired_scale,ls,lower_lim,upper_lim,obj,split_by_eddington=True,median=True)
        jj+=1
    ii+=1

# %%
def make_plot(run,desired_scale,ls,lower_lim,upper_lim,obj,split_by_eddington=False,median=False):
    redshift_space=numpy.array([0.0,1.5,3,4])
    if (run=='MBII'):
        redshift_space=numpy.array([0.06,1.5,3,4])
        
    
    log_LINKING_LENGTH_space=numpy.linspace(-2,2,40)
    scale_of_interest_space=numpy.array([1.0,0.1,0.015])
    N_space=numpy.arange(1,50)
    cols=['blue','red','green','cyan']
    skip=3
    redshift=1
    save_output_path='/ufrc/lblecha/aklantbhowmick/richness_output_AGN_activity/'

    RR_active_interest=1


    ii=0

    for scale_of_interest in [desired_scale]:

        jj=0
        
        #if (ii==2):
        #run='L75n1820TNG'
        
        for redshift,col in zip(redshift_space,col_space):
            #print(log_scale_of_interest)
            #obj=ax[0,jj]
            #obj2=ax[1,jj]
            #if (ii==0):
            #    obj.set_title('$\log_{10}M_{bh}[M_{\odot}/h]>%.2f$'%log_bhmass_cut,fontsize=25)

            #obj.tick_params(labelsize=30)            
            #obj2.tick_params(labelsize=30)



            if (1==1):
                #obj.set_xlabel('Redshift',fontsize=25)           #    obj2.set_xlabel('$RICHNESS$',fontsize=30

                log_scale_of_interest=log_LINKING_LENGTH_space[log_LINKING_LENGTH_space<numpy.log10(scale_of_interest)][-1]  
                #obj.text(0.5,0.9,'$\log_{10}M_{bh}[M_{\odot}/h]>%.2f$'%log_bhmass_cut,horizontalalignment='center',verticalalignment='center', transform=obj.transAxes,fontsize=20)  
                fraction_upper_space=[]
                d_fraction_upper_space=[] 
                fraction_lower_space=[]
                d_fraction_lower_space=[]

                for log_lum_cut in log_lum_cut_space:
                    if (median==True):
                        #print('Using medians')
                        if (split_by_eddington==False):
                            RICHNESS,RICHNESS_active_42,RICHNESS_active_43,RICHNESS_active_44,RICHNESS_active_45,RICHNESS_active_46,RICHNESS_active_47,RICHNESS_BH_70,RICHNESS_BH_80,RICHNESS_BH_90,RICHNESS_BH_100,primary_tag,primary_half_by_halomass,primary_half_by_bhmass,BH_Mass_primary,bolometric_luminosity_primary,host_halo_mass_primary=numpy.load(save_output_path+run+'log_bhmass_cut_%.1f_redshift_%.2f_log_LINKING_LENGTH_%.2f_all_info_more_bound_median.npy'%(log_bhmass_cut,redshift,log_scale_of_interest))
                        if (split_by_eddington==True):
                            RICHNESS,RICHNESS_active_42,RICHNESS_active_43,RICHNESS_active_44,RICHNESS_active_45,RICHNESS_active_46,RICHNESS_active_47,RICHNESS_BH_70,RICHNESS_BH_80,RICHNESS_BH_90,RICHNESS_BH_100,primary_tag,primary_half_by_halomass,primary_half_by_bhmass,primary_half_by_stellarmass,BH_Mass_primary,bolometric_luminosity_primary,host_halo_mass_primary,host_subhalo_SM_primary=numpy.load(save_output_path+run+'log_bhmass_cut_%.1f_redshift_%.2f_log_LINKING_LENGTH_%.2f_all_info_more_split_by_Ledd_bound_median.npy'%(log_bhmass_cut,redshift,log_scale_of_interest))

                    else:
                        if (split_by_eddington==False):
                            RICHNESS,RICHNESS_active_42,RICHNESS_active_43,RICHNESS_active_44,RICHNESS_active_45,RICHNESS_active_46,RICHNESS_active_47,RICHNESS_BH_70,RICHNESS_BH_80,RICHNESS_BH_90,RICHNESS_BH_100,primary_tag,primary_half_by_halomass,primary_half_by_bhmass,BH_Mass_primary,bolometric_luminosity_primary,host_halo_mass_primary=numpy.load(save_output_path+run+'log_bhmass_cut_%.1f_redshift_%.2f_log_LINKING_LENGTH_%.2f_all_info_more_bound.npy'%(log_bhmass_cut,redshift,log_scale_of_interest))
                        if (split_by_eddington==True):
                            RICHNESS,RICHNESS_active_42,RICHNESS_active_43,RICHNESS_active_44,RICHNESS_active_45,RICHNESS_active_46,RICHNESS_active_47,RICHNESS_BH_70,RICHNESS_BH_80,RICHNESS_BH_90,RICHNESS_BH_100,primary_tag,primary_half_by_halomass,primary_half_by_bhmass,BH_Mass_primary,bolometric_luminosity_primary,host_halo_mass_primary=numpy.load(save_output_path+run+'log_bhmass_cut_%.1f_redshift_%.2f_log_LINKING_LENGTH_%.2f_all_info_more_split_by_Ledd_bound.npy'%(log_bhmass_cut,redshift,log_scale_of_interest))
                       
                    mask_halo=host_halo_mass_primary>10**log_halo_mass_cut
                    if (log_lum_cut==44):
                        RICHNESS_active=RICHNESS_active_44
                    if (log_lum_cut==43):
                        RICHNESS_active=RICHNESS_active_43
                    if (log_lum_cut==42):
                        RICHNESS_active=RICHNESS_active_42
                    if (log_lum_cut==45):
                        RICHNESS_active=RICHNESS_active_45
                    if (log_lum_cut==46):
                        RICHNESS_active=RICHNESS_active_46
                    if (log_lum_cut==47):
                        RICHNESS_active=RICHNESS_active_47                    
                    
                    
                    extract_upper_system=((RICHNESS>=RR_active_interest)&(RICHNESS_active>=1))&mask_halo
             
                    RICHNESS_selected=RICHNESS[extract_upper_system]          
                    fraction=float(len(RICHNESS_selected[RICHNESS_selected>=RR]))/(len(RICHNESS_selected)+0.0000001)    
                    fraction_upper_space.append(fraction)  
                    d_fraction=numpy.sqrt(float(len(RICHNESS_selected[RICHNESS_selected>=RR])))/(len(RICHNESS_selected)+0.0000001)    
                    d_fraction_upper_space.append(d_fraction) 



                fraction_upper_space=numpy.array(fraction_upper_space)
                d_fraction_upper_space=numpy.array(d_fraction_upper_space)


                mask_upper=(fraction_upper_space>0)&(d_fraction_upper_space<0.5)

                labl='$z=%.2f$'%redshift
                obj.errorbar(log_lum_cut_space[mask_upper],fraction_upper_space[mask_upper],d_fraction_upper_space[mask_upper],color=col,linewidth=2,label=labl,marker=' ',linestyle='solid')                 
                obj.set_yscale('log')
                obj.set_ylim(lower_lim,upper_lim)

                

                
            jj+=1
        #ax.set_ylabel('fraction',fontsize=30)
        #ax[1,0].set_ylabel('$\log_{10}{Upper half}-\log_{10}lower half$',fontsize=30)
        ii+=1

# %%
f,ax=plt.subplots(3,3,figsize=(10,12),sharex=False)


ls='solid'

col_space=['blue','red','green','cyan']
log_lum_cut_space=numpy.array([42,43,44,45])


log_halo_mass_cut=10.
log_bhmass_cut=6.0


run='L75n1820TNG'
RR=2
ii=0
for desired_scale in [1.0,0.1,0.015]:
    if (desired_scale==1.0):
        lower_lim=1e-2
        upper_lim=1.1
    if (desired_scale==0.1):
        lower_lim=1e-4
        upper_lim=1.0
    
    
    jj=0
    ax[ii,1].set_title('$d_{max}=%.2f\ \mathrm{Mpc}/h$'%desired_scale,fontsize=20)
    ax[ii,0].set_ylabel('$f_{\mathrm{system}}$',fontsize=30)
    
    for RR in [2,3,4]:
        obj=ax[ii,jj]
        obj.text(0.5,0.9,'$R>%d$'%RR,horizontalalignment='center',verticalalignment='center', transform=obj.transAxes,fontsize=20)  

        make_plot(run,desired_scale,ls,lower_lim,upper_lim,obj,split_by_eddington=True,median=True)
        ax[2,1].set_xlabel('$\log\ L(>)[\mathrm{ergs/sec}]$',fontsize=30)
        
        obj.tick_params(labelsize=20)
        if (jj>=1):
            obj.tick_params(labelleft=False)
        
        
        jj+=1
    ii+=1
    
plt.subplots_adjust(wspace=0,hspace=0.3)

ax[0,0].legend(fontsize=15,loc='lower right',frameon=False)

plt.savefig('./figures_for_paper1/AGNs_that_are_systems_%s.png'%run,bbox_inches='tight')

# %%
f,ax=plt.subplots(3,3,figsize=(10,12),sharex=True)


ls='solid'

col_space=['blue','red','green','cyan']
log_lum_cut_space=numpy.array([42,43,44,45])


log_halo_mass_cut=10.
log_bhmass_cut=6.0


run='MBII'
RR=2
ii=0
for desired_scale in [1.0,0.1,0.015]:
    if (desired_scale==1.0):
        lower_lim=1e-2
        upper_lim=3
    if (desired_scale==0.1):
        lower_lim=1e-4
        upper_lim=3
    
    
    jj=0
    ax[ii,1].set_title('$d_{max}=%.2f$'%desired_scale,fontsize=20)
    ax[ii,0].set_ylabel('$f_{\mathrm{system}}$',fontsize=30)
    
    for RR in [2,3,4]:
        obj=ax[ii,jj]
        obj.text(0.5,0.9,'$R>%d$'%RR,horizontalalignment='center',verticalalignment='center', transform=obj.transAxes,fontsize=20)  

        make_plot(run,desired_scale,ls,lower_lim,upper_lim,obj,split_by_eddington=True,median=True)
        ax[2,1].set_xlabel('$\log\ L(>)[\mathrm{ergs/sec}]$',fontsize=30)
        
        obj.tick_params(labelsize=25)
        if (jj>=1):
            obj.tick_params(labelleft=False)
        
        
        jj+=1
    ii+=1
    
plt.subplots_adjust(wspace=0)

ax[0,0].legend(fontsize=15,loc='lower right',frameon=False)

plt.savefig('./figures_for_paper1/AGNs_that_are_systems_%s.png'%run,bbox_inches='tight')

# %%
def make_plot(run,desired_scale,ls,lower_lim,upper_lim,split_by_eddington=False,median=False,select_by_bhmass=False,select_by_stellarmass=False):
    redshift_space=numpy.array([0.0,0.6,1,1.5,2,2.5,3,3.5,4.0])
    if (run=='MBII'):
        redshift_space=numpy.array([0.06,0.6,1,1.5,2,2.5,3,3.5,4.0])
        
    
    log_LINKING_LENGTH_space=numpy.linspace(-2,2,40)
    scale_of_interest_space=numpy.array([1.0,0.1,0.015])
    N_space=numpy.arange(1,50)
    cols=['blue','red','green','cyan']
    skip=3
    redshift=1
    save_output_path='/ufrc/lblecha/aklantbhowmick/richness_output_AGN_activity/'

    RR_active_interest=1


    ii=0

    for scale_of_interest in [desired_scale]:

        jj=0
        
        #if (ii==2):
        #run='L75n1820TNG'
        
        for RR in [2,3,4]:
            #print(log_scale_of_interest)
            #run='L75n1820TNG'
            
            #if (log_bhmass_cut==8):
            #    run='L205n2500TNG'
            
            
            obj=ax[0,jj]
            obj2=ax[1,jj]
            if (ii==0):
                obj.set_title('$R>%d$'%RR,fontsize=25)






            obj.tick_params(labelsize=30)
            
            obj2.tick_params(labelsize=30)

            #if (ii==len(log_bhmass_cuts_space)-1):


            #obj.set_xlim(10**-2.5,10**2.5)
            #obj.set_ylim(1e-3,10)

            #obj.set_yscale('log')

            if (1==1):
                #obj.set_xlabel('Redshift',fontsize=25)           #    obj2.set_xlabel('$RICHNESS$',fontsize=30

                log_scale_of_interest=log_LINKING_LENGTH_space[log_LINKING_LENGTH_space<numpy.log10(scale_of_interest)][-1]  



                #obj.text(0.5,0.9,'$\log_{10}M_{bh}[M_{\odot}/h]>%.2f$'%log_bhmass_cut,horizontalalignment='center',verticalalignment='center', transform=obj.transAxes,fontsize=20)  
                fraction_upper_space=[]
                d_fraction_upper_space=[] 
                fraction_lower_space=[]
                d_fraction_lower_space=[]

                for redshift in redshift_space:
                    if (median==True):
                        if (split_by_eddington==False):
                            RICHNESS,RICHNESS_active_42,RICHNESS_active_43,RICHNESS_active_44,RICHNESS_active_45,RICHNESS_active_46,RICHNESS_active_47,RICHNESS_BH_70,RICHNESS_BH_80,RICHNESS_BH_90,RICHNESS_BH_100,primary_tag,primary_half_by_halomass,primary_half_by_bhmass,primary_half_by_stellarmass,BH_Mass_primary,bolometric_luminosity_primary,host_halo_mass_primary,host_subhalo_SM_primary=numpy.load(save_output_path+run+'log_bhmass_cut_%.1f_redshift_%.2f_log_LINKING_LENGTH_%.2f_all_info_more_bound_median.npy'%(log_bhmass_cut,redshift,log_scale_of_interest))
                        if (split_by_eddington==True):
                            RICHNESS,RICHNESS_active_42,RICHNESS_active_43,RICHNESS_active_44,RICHNESS_active_45,RICHNESS_active_46,RICHNESS_active_47,RICHNESS_BH_70,RICHNESS_BH_80,RICHNESS_BH_90,RICHNESS_BH_100,primary_tag,primary_half_by_halomass,primary_half_by_bhmass,primary_half_by_stellarmass,BH_Mass_primary,bolometric_luminosity_primary,host_halo_mass_primary,host_subhalo_SM_primary=numpy.load(save_output_path+run+'log_bhmass_cut_%.1f_redshift_%.2f_log_LINKING_LENGTH_%.2f_all_info_more_split_by_Ledd_bound_median.npy'%(log_bhmass_cut,redshift,log_scale_of_interest))

                    else:
                        if (split_by_eddington==False):
                            RICHNESS,RICHNESS_active_42,RICHNESS_active_43,RICHNESS_active_44,RICHNESS_active_45,RICHNESS_active_46,RICHNESS_active_47,RICHNESS_BH_70,RICHNESS_BH_80,RICHNESS_BH_90,RICHNESS_BH_100,primary_tag,primary_half_by_halomass,primary_half_by_bhmass,BH_Mass_primary,bolometric_luminosity_primary,host_halo_mass_primary=numpy.load(save_output_path+run+'log_bhmass_cut_%.1f_redshift_%.2f_log_LINKING_LENGTH_%.2f_all_info_more_bound.npy'%(log_bhmass_cut,redshift,log_scale_of_interest))
                        if (split_by_eddington==True):
                            RICHNESS,RICHNESS_active_42,RICHNESS_active_43,RICHNESS_active_44,RICHNESS_active_45,RICHNESS_active_46,RICHNESS_active_47,RICHNESS_BH_70,RICHNESS_BH_80,RICHNESS_BH_90,RICHNESS_BH_100,primary_tag,primary_half_by_halomass,primary_half_by_bhmass,BH_Mass_primary,bolometric_luminosity_primary,host_halo_mass_primary=numpy.load(save_output_path+run+'log_bhmass_cut_%.1f_redshift_%.2f_log_LINKING_LENGTH_%.2f_all_info_more_split_by_Ledd_bound.npy'%(log_bhmass_cut,redshift,log_scale_of_interest))
                       
                    mask_halo=(host_halo_mass_primary<10**log_halo_mass_cut_max)&(host_halo_mass_primary>10**log_halo_mass_cut_min)
                    if (select_by_bhmass):
                        labl='BH mass'
                        extract_upper_system=((RICHNESS>=RR_active_interest)&(primary_half_by_bhmass==1))&mask_halo
                        extract_lower_system=((RICHNESS>=RR_active_interest)&(primary_half_by_bhmass==-1))&mask_halo
                    
                    elif(select_by_stellarmass):
                        labl='$d_{\mathrm{max}}=%.2f \ \mathrm{Mpc}/h$'%desired_scale
                        extract_upper_system=((RICHNESS>=RR_active_interest)&(primary_half_by_stellarmass==1))&mask_halo
                        extract_lower_system=((RICHNESS>=RR_active_interest)&(primary_half_by_stellarmass==-1))&mask_halo
                    
                    else:
                        labl='Halo mass'
                        extract_upper_system=((RICHNESS>=RR_active_interest)&(primary_half_by_halomass==1))&mask_halo
                        extract_lower_system=((RICHNESS>=RR_active_interest)&(primary_half_by_halomass==-1))&mask_halo                    
                    
                    RICHNESS_selected=RICHNESS[extract_upper_system]          
                    fraction=float(len(RICHNESS_selected[RICHNESS_selected>=RR]))/(len(RICHNESS_selected)+0.0000001)    
                    fraction_upper_space.append(fraction)  
                    d_fraction=numpy.sqrt(float(len(RICHNESS_selected[RICHNESS_selected>=RR])))/(len(RICHNESS_selected)+0.0000001)    
                    d_fraction_upper_space.append(d_fraction) 

                    RICHNESS_selected=RICHNESS[extract_lower_system]
                    fraction=float(len(RICHNESS_selected[RICHNESS_selected>=RR]))/(len(RICHNESS_selected)+0.0000001)    
                    fraction_lower_space.append(fraction)  
                    d_fraction=numpy.sqrt(float(len(RICHNESS_selected[RICHNESS_selected>=RR])))/(len(RICHNESS_selected)+0.0000001)    
                    d_fraction_lower_space.append(d_fraction) 

                fraction_upper_space=numpy.array(fraction_upper_space)
                d_fraction_upper_space=numpy.array(d_fraction_upper_space)

                fraction_lower_space=numpy.array(fraction_lower_space)
                d_fraction_lower_space=numpy.array(d_fraction_lower_space)

                mask_upper=(fraction_upper_space>0)&(d_fraction_upper_space<0.5)
                mask_lower=(fraction_lower_space>0)&(d_fraction_lower_space<0.5)

                #print(fraction_upper_space)
                obj.errorbar(redshift_space[mask_upper]+offset,fraction_upper_space[mask_upper],d_fraction_upper_space[mask_upper],color=col1,linewidth=2,label=labl,marker=' ',linestyle=ls) 
                obj.errorbar(redshift_space[mask_lower]+offset,fraction_lower_space[mask_lower],d_fraction_lower_space[mask_lower],color=col2,linewidth=2,marker=' ',linestyle=ls)             
                
                diff_log=numpy.log10(fraction_upper_space[mask_upper&mask_lower])-numpy.log10(fraction_lower_space[mask_upper&mask_lower])
                d_diff_log_u=d_fraction_upper_space[mask_upper&mask_lower]/fraction_upper_space[mask_upper&mask_lower]/numpy.log(10)#)-numpy.log10(fraction_lower_space[mask_upper&mask_lower])
                d_diff_log_l=d_fraction_lower_space[mask_upper&mask_lower]/fraction_lower_space[mask_upper&mask_lower]/numpy.log(10)
                 
                obj2.errorbar(redshift_space[mask_upper&mask_lower]+offset,diff_log,d_diff_log_u+d_diff_log_l,color=col1,linewidth=2,label=labl,marker=' ',linestyle=ls) 

                obj.set_yscale('log')
                obj.set_ylim(lower_lim,upper_lim)
                obj2.set_ylim(-1.5,1.5)
                obj2.axhline(0,linewidth=1,color='red')
                obj.set_xlim(0,4.5)
                obj2.set_xlabel('Redshift',fontsize=30)
                if (jj>0):
                    obj.tick_params(labelleft=False)
                    obj2.tick_params(labelleft=False)
                
            jj+=1

        ii+=1

# %%
log_halo_mass_cut_max=14.5
log_halo_mass_cut_min=10.5
f,ax=plt.subplots(2,3,figsize=(17,12),sharex=True)


run='MBII'



medians=True
#make_plot(run,1.0,'dashed',1e-2,1e0,split_by_eddington=False,median=medians,select_by_stellarmass=True)
#RR=2
log_bhmass_cut=6
col1='blue'
col2='red'
ls='solid'
offset=0

RR=4
make_plot(run,1.0,'solid',1e-4,1e0,split_by_eddington=True,median=medians,select_by_stellarmass=True)

offset=0.1
ls='dashed'
make_plot(run,0.1,'dashed',1e-4,1e0,split_by_eddington=True,median=medians,select_by_stellarmass=True)

#col='green'
#make_plot(run,0.015,'solid',1e-5,1e0,split_by_eddington=True,median=medians,select_by_stellarmass=True)
offset=0.01
ls='dotted'
make_plot(run,0.015,'dotted',1e-4,1e0,split_by_eddington=True,median=medians,select_by_stellarmass=True)


#RR=3
#make_plot(run,1.0,'dashed',1e-2,1e0,split_by_eddington=True,median=medians,select_by_stellarmass=True)


ax[0,0].set_ylabel('$f_{R>}$',fontsize=40)
ax[1,0].set_ylabel('$\log_{10}({f^+_{R>}/f^-_{R>}})$',fontsize=40)


ax[0,2].legend(loc='upper left',fontsize=14,frameon=False)

plt.subplots_adjust(hspace=0,wspace=0)
plt.savefig('./figures_for_paper1/upper_lower_quartile_%s.png'%run)

#ax[1,0].set_ylabel('$\log_{10}{Upper half}-\log_{10}lower half$',fontsize=30)

# %%
log_halo_mass_cut_max=14.5
log_halo_mass_cut_min=10.5
f,ax=plt.subplots(2,3,figsize=(17,12),sharex=True)


run='L75n1820TNG'



medians=True
#make_plot(run,1.0,'dashed',1e-2,1e0,split_by_eddington=False,median=medians,select_by_stellarmass=True)
#RR=2
log_bhmass_cut=6
col1='blue'
col2='red'
ls='solid'
offset=0

RR=4
make_plot(run,1.0,'solid',1e-4,1e0,split_by_eddington=True,median=medians,select_by_stellarmass=True)

offset=0.1
ls='dashed'
make_plot(run,0.1,'dashed',1e-4,1e0,split_by_eddington=True,median=medians,select_by_stellarmass=True)

#col='green'
#make_plot(run,0.015,'solid',1e-5,1e0,split_by_eddington=True,median=medians,select_by_stellarmass=True)
offset=0.01
ls='dotted'
make_plot(run,0.015,'dotted',1e-4,1e0,split_by_eddington=True,median=medians,select_by_stellarmass=True)


#RR=3
#make_plot(run,1.0,'dashed',1e-2,1e0,split_by_eddington=True,median=medians,select_by_stellarmass=True)


ax[0,0].set_ylabel('$f_{R>}$',fontsize=40)
ax[1,0].set_ylabel('$\log_{10}({f^+_{R>}/f^-_{R>}})$',fontsize=40)


ax[0,2].legend(loc='upper left',fontsize=14,frameon=False)

plt.subplots_adjust(hspace=0,wspace=0)

plt.savefig('./figures_for_paper1/upper_lower_quartile_%s.png'%run)
#ax[1,0].set_ylabel('$\log_{10}{Upper half}-\log_{10}lower half$',fontsize=30)

# %%
log_halo_mass_cut_max=12
log_halo_mass_cut_min=11.0
f,ax=plt.subplots(2,3,figsize=(17,12),sharex=True)


run='L75n1820TNG'



medians=True
#make_plot(run,1.0,'dashed',1e-2,1e0,split_by_eddington=False,median=medians,select_by_stellarmass=True)
#RR=2
log_bhmass_cut=6
col1='blue'
col2='red'
ls='solid'
offset=0

RR=4
make_plot(run,1.0,'solid',1e-4,1e0,split_by_eddington=True,median=medians,select_by_stellarmass=True)

offset=0.1
ls='dashed'
make_plot(run,0.1,'dashed',1e-4,1e0,split_by_eddington=True,median=medians,select_by_stellarmass=True)

#col='green'
#make_plot(run,0.015,'solid',1e-5,1e0,split_by_eddington=True,median=medians,select_by_stellarmass=True)
offset=0.01
ls='dotted'
make_plot(run,0.015,'dotted',1e-4,1e0,split_by_eddington=True,median=medians,select_by_stellarmass=True)


#RR=3
#make_plot(run,1.0,'dashed',1e-2,1e0,split_by_eddington=True,median=medians,select_by_stellarmass=True)


ax[0,0].set_ylabel('$f_{R>}$',fontsize=40)
ax[1,0].set_ylabel('$\log_{10}({f^+_{R>}/f^-_{R>}})$',fontsize=40)


ax[0,2].legend(loc='upper left',fontsize=20,frameon=False)

plt.subplots_adjust(hspace=0,wspace=0)

plt.savefig('./figures_for_paper1/upper_lower_quartile_%s_proper_range.png'%run)

#ax[1,0].set_ylabel('$\log_{10}{Upper half}-\log_{10}lower half$',fontsize=30)

# %%
run='L75n1820TNG'
simulation='Illustris_TNG'
load_output_path_snap='/ufrc/lblecha/aklantbhowmick/%s_BHs/'%simulation
f,ax=plt.subplots(1,3,figsize=(17,5),sharex=True)
i=0
for redshift in [0.0,1.5,3]:
    obj=ax[i]
    
    
    obj.set_title('$z=%.1f$'%redshift,fontsize=30)
    hf_half = h5py.File(load_output_path_snap+run+'bh_lum_host_halo_with_id_and_mass_z%.2f_and_sub_halo_id_added_velocity_all_BHs_division_eddington_ratio_max_lum_median'%(redshift))
    hf = h5py.File(load_output_path_snap+run+'bh_lum_host_halo_with_id_and_mass_z%.2f_and_sub_halo_id_added_velocity_all_BHs'%(redshift))
    hf_tag = h5py.File(load_output_path_snap+run+'bh_lum_host_halo_with_id_and_mass_z%.2f_and_sub_halo_id_added_velocity_all_BHs_tag_max_lum'%(redshift))

    half=hf_half.get('half_by_stellarmass')[:]
    tag=hf_tag.get('central_satellite_tag')[:]
    host_halo_id=hf.get('host_halo_id')[:]    
    stellar_mass=hf.get('host_subhalo_SM')[:]
    
    bhmass=hf.get('mass')[:]
    L_bol=hf.get('L_bol')[:]
    eddington_ratio=2.*L_bol/bhmass/1.26e38
    

    
    boxsize=hf.get('box_size')
    if (run=='MBII'):
        boxsize_in_Kpc=100000.
    else:
        boxsize_in_Kpc=boxsize.value*1000.
    
 
    
    
    get_upper=((half==1)&(stellar_mass>0))&(tag==1)
    get_lower=((half==-1)&(stellar_mass>0))&(tag==1)
    
    

    obj.errorbar(stellar_mass[get_upper],eddington_ratio[get_upper],color='blue',marker='o',linestyle=' ',alpha=0.3)
    

    obj.errorbar(stellar_mass[get_lower],eddington_ratio[get_lower],color='red',marker='o',linestyle=' ',alpha=0.3)
    
    #obj2.errorbar(HM_bin,HMF/HMF2,dHMF/HMF2,color='blue')
    
    #print(len(halo_mass[get_upper]),len(halo_mass[get_lower]))
    #print(len(host_halo_id[tag==1]),len(numpy.unique(host_halo_id[tag==1])))
    
   # obj2.axvspan(10**11,10**12,color='green',alpha=0.2)
    #obj.axvspan(10**11,10**12,color='green',alpha=0.2)
    print(len(stellar_mass[get_upper]),len(stellar_mass[get_lower]))
    #print(len(host_halo_id[tag==1]),len(numpy.unique(host_halo_id[tag==1])))
    
     
    obj.set_xscale('log')
    #obj2.set_xscale('log')
    obj.set_yscale('log')
    
    #obj.
    
    #obj2.set_ylim(0.8,1.2)
    
    obj.set_xlabel('$M_*(M_{\odot}/h)$',fontsize=35)
    
    if (i>=1):
        obj.tick_params(labelleft=False)
        #obj2.tick_params(labelleft=False)
    obj.tick_params(labelsize=25)
    #obj2.tick_params(labelsize=25)        
    i+=1
    
ax[0].set_ylabel(r'$\eta=L/L_{\mathrm{edd}}$',fontsize=25)

#ax[1,0].set_ylabel('Ratio',fontsize=25)
plt.subplots_adjust(hspace=0,wspace=0)
# Out:
# 12930 12911
# 13012 12971
# 8885 8966

# %%
run='L75n1820TNG'
simulation='Illustris_TNG'
load_output_path_snap='/ufrc/lblecha/aklantbhowmick/%s_BHs/'%simulation
f,ax=plt.subplots(2,3,figsize=(17,7), gridspec_kw={'height_ratios': [4, 2]},sharex=True)
i=0
for redshift in [0.0,1.5,3]:
    obj=ax[0,i]
    obj2=ax[1,i]
    
    obj.set_title('$z=%.1f$'%redshift,fontsize=30)
    hf_half = h5py.File(load_output_path_snap+run+'bh_lum_host_halo_with_id_and_mass_z%.2f_and_sub_halo_id_added_velocity_all_BHs_division_max_lum_median'%(redshift))
    hf = h5py.File(load_output_path_snap+run+'bh_lum_host_halo_with_id_and_mass_z%.2f_and_sub_halo_id_added_velocity_all_BHs'%(redshift))
    hf_tag = h5py.File(load_output_path_snap+run+'bh_lum_host_halo_with_id_and_mass_z%.2f_and_sub_halo_id_added_velocity_all_BHs_tag_max_lum'%(redshift))

    half=hf_half.get('half_by_stellarmass')[:]
    tag=hf_tag.get('central_satellite_tag')[:]
    host_halo_id=hf.get('host_halo_id')[:]    
    halo_mass=hf.get('host_halo_mass')[:]
    boxsize=hf.get('box_size')
    if (run=='MBII'):
        boxsize_in_Kpc=100000.
    else:
        boxsize_in_Kpc=boxsize.value*1000.
    
 
    
    
    get_upper=(half==1)&(tag==1)
    get_lower=(half==-1)&(tag==1)
    
    
    HM_bin,HMF,dHMF=arepo_package.mass_function(halo_mass[get_upper],boxsize_in_Kpc,20,10,14)
    obj.errorbar(HM_bin,HMF,dHMF,color='blue')
    
    HM_bin,HMF2,dHMF2=arepo_package.mass_function(halo_mass[get_lower],boxsize_in_Kpc,20,10,14)
    obj.errorbar(HM_bin,HMF2,dHMF2,color='red')
    
    obj2.errorbar(HM_bin,HMF/HMF2,dHMF/HMF2,color='blue')
    
    print(len(halo_mass[get_upper]),len(halo_mass[get_lower]))
    print(len(host_halo_id[tag==1]),len(numpy.unique(host_halo_id[tag==1])))
    
    obj2.axvspan(10**11,10**12,color='green',alpha=0.2)
    obj.axvspan(10**11,10**12,color='green',alpha=0.2)
    
     
    obj.set_xscale('log')
    obj2.set_xscale('log')
    obj.set_yscale('log')
    
    obj2.set_ylim(0.8,1.2)
    
    obj2.set_xlabel('$M_h(M_{\odot}/h)$',fontsize=35)
    
    if (i>=1):
        obj.tick_params(labelleft=False)
        obj2.tick_params(labelleft=False)
    obj.tick_params(labelsize=25)
    obj2.tick_params(labelsize=25)        
    i+=1
    
ax[0,0].set_ylabel('$dn/dM_h(\mathrm{Mpc}^{-3}h^3 M_{\odot}^{-1})$',fontsize=25)

ax[1,0].set_ylabel('Ratio',fontsize=25)
plt.subplots_adjust(hspace=0,wspace=0)
plt.savefig('mass_function_%s.png'%run,bbox_inches='tight')
# Out:
# /apps/jupyterhub/1.0.0/lib/python3.7/site-packages/ipykernel_launcher.py:38: RuntimeWarning: divide by zero encountered in true_divide
# /home/aklantbhowmick/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_axes.py:3199: RuntimeWarning: invalid value encountered in double_scalars
#   low = [thisx - thiserr for thisx, thiserr
# /apps/jupyterhub/1.0.0/lib/python3.7/site-packages/ipykernel_launcher.py:38: RuntimeWarning: invalid value encountered in true_divide
# 12929 12924
# 25853 25853
# 13022 12967
# 25989 25989
# 8966 8893
# 17859 17859

# %%
run='MBII'
simulation='MBII'
load_output_path_snap='/ufrc/lblecha/aklantbhowmick/%s_BHs/'%simulation
f,ax=plt.subplots(2,3,figsize=(17,7), gridspec_kw={'height_ratios': [4, 2]},sharex=True)
i=0
for redshift in [0.06,1.5,3]:
    obj=ax[0,i]
    obj2=ax[1,i]
    
    obj.set_title('$z=%.1f$'%redshift,fontsize=30)
    hf_half = h5py.File(load_output_path_snap+run+'bh_lum_host_halo_with_id_and_mass_z%.2f_and_sub_halo_id_added_velocity_all_BHs_division_max_lum_median'%(redshift))
    hf = h5py.File(load_output_path_snap+run+'bh_lum_host_halo_with_id_and_mass_z%.2f_and_sub_halo_id_added_velocity_all_BHs'%(redshift))
    hf_tag = h5py.File(load_output_path_snap+run+'bh_lum_host_halo_with_id_and_mass_z%.2f_and_sub_halo_id_added_velocity_all_BHs_tag_max_lum'%(redshift))

    half=hf_half.get('half_by_stellarmass')[:]
    tag=hf_tag.get('central_satellite_tag')[:]
    host_halo_id=hf.get('host_halo_id')[:]    
    halo_mass=hf.get('host_halo_mass')[:]
    boxsize=hf.get('box_size')
    if (run=='MBII'):
        boxsize_in_Kpc=100000.
    else:
        boxsize_in_Kpc=boxsize.value*1000.
    
 
    
    
    get_upper=(half==1)&(tag==1)
    get_lower=(half==-1)&(tag==1)
    
    
    HM_bin,HMF,dHMF=arepo_package.mass_function(halo_mass[get_upper],boxsize_in_Kpc,20,10,14)
    obj.errorbar(HM_bin,HMF,dHMF,color='blue')
    
    HM_bin,HMF2,dHMF2=arepo_package.mass_function(halo_mass[get_lower],boxsize_in_Kpc,20,10,14)
    obj.errorbar(HM_bin,HMF2,dHMF2,color='red')
    
    obj2.errorbar(HM_bin,HMF/HMF2,dHMF/HMF2,color='blue')
    
    print(len(halo_mass[get_upper]),len(halo_mass[get_lower]))
    print(len(host_halo_id[tag==1]),len(numpy.unique(host_halo_id[tag==1])))
    
    #obj2.axvspan(10**11,10**12,color='green',alpha=0.2)
    #obj.axvspan(10**11,10**12,color='green',alpha=0.2)
    
     
    obj.set_xscale('log')
    obj2.set_xscale('log')
    obj.set_yscale('log')
    
    obj2.set_ylim(0.8,1.4)
    
    obj2.set_xlabel('$M_h(M_{\odot}/h)$',fontsize=35)
    
    if (i>=1):
        obj.tick_params(labelleft=False)
        obj2.tick_params(labelleft=False)
    obj.tick_params(labelsize=25)
    obj2.tick_params(labelsize=25)        
    i+=1
    
ax[0,0].set_ylabel('$dn/dM_h(\mathrm{Mpc}^{-3}h^3 M_{\odot}^{-1})$',fontsize=25)

ax[1,0].set_ylabel('Ratio',fontsize=25)
plt.subplots_adjust(hspace=0,wspace=0)
# Out:
# 25593 25852
# 51445 51445
# 23980 24044
# 48024 48024
# 15230 15290
# 30520 30520
# /apps/jupyterhub/1.0.0/lib/python3.7/site-packages/ipykernel_launcher.py:38: RuntimeWarning: divide by zero encountered in true_divide
# /apps/jupyterhub/1.0.0/lib/python3.7/site-packages/ipykernel_launcher.py:38: RuntimeWarning: invalid value encountered in true_divide

# %%
run='L75n1820TNG'
simulation='Illustris_TNG'
load_output_path_snap='/ufrc/lblecha/aklantbhowmick/%s_BHs/'%simulation
f,ax=plt.subplots(1,3,figsize=(15,4))
i=0
for redshift in [0.0,2,4]:
    obj=ax[i]
    hf_half = h5py.File(load_output_path_snap+run+'bh_lum_host_halo_with_id_and_mass_z%.2f_and_sub_halo_id_added_velocity_all_BHs_division_max_lum_median'%(redshift))
    hf = h5py.File(load_output_path_snap+run+'bh_lum_host_halo_with_id_and_mass_z%.2f_and_sub_halo_id_added_velocity_all_BHs'%(redshift))
    hf_tag = h5py.File(load_output_path_snap+run+'bh_lum_host_halo_with_id_and_mass_z%.2f_and_sub_halo_id_added_velocity_all_BHs_tag_max_lum'%(redshift))

    half=hf_half.get('half_by_stellarmass')[:]
    tag=hf_tag.get('central_satellite_tag')[:]
    host_halo_id=hf.get('host_halo_id')[:]    
    halo_mass=hf.get('host_subhalo_SM')[:]
    boxsize=hf.get('box_size')
    if (run=='MBII'):
        boxsize_in_Kpc=100000.
    else:
        boxsize_in_Kpc=boxsize.value*1000.
    
 
    
    
    get_upper=(half==1)&(tag==1)
    get_lower=(half==-1)&(tag==1)
    
    
    HM_bin,HMF,dHMF=arepo_package.mass_function(halo_mass[get_upper],boxsize_in_Kpc,20,7,10)
    obj.errorbar(HM_bin,HMF,dHMF,color='blue')
    
    HM_bin,HMF,dHMF=arepo_package.mass_function(halo_mass[get_lower],boxsize_in_Kpc,20,7,10)
    obj.errorbar(HM_bin,HMF,dHMF,color='red')
    
    print(len(halo_mass[get_upper]),len(halo_mass[get_lower]))
    print(len(host_halo_id[tag==1]),len(numpy.unique(host_halo_id[tag==1])))
     
    obj.set_xscale('log')
    obj.set_yscale('log')
    i+=1
# Out:
# 12929 12924
# 25853 25853
# 11647 11603
# 23250 23250
# 5219 5211
# 10430 10430

# %%
run='L75n1820TNG'
simulation='Illustris_TNG'
load_output_path_snap='/ufrc/lblecha/aklantbhowmick/%s_BHs/'%simulation
f,ax=plt.subplots(1,3,figsize=(15,4))
i=0
for redshift in [0.0,2,4]:
    obj=ax[i]
    hf_half = h5py.File(load_output_path_snap+run+'bh_lum_host_halo_with_id_and_mass_z%.2f_and_sub_halo_id_added_velocity_all_BHs_division_max_lum_median'%(redshift))
    hf = h5py.File(load_output_path_snap+run+'bh_lum_host_halo_with_id_and_mass_z%.2f_and_sub_halo_id_added_velocity_all_BHs'%(redshift))
    hf_tag = h5py.File(load_output_path_snap+run+'bh_lum_host_halo_with_id_and_mass_z%.2f_and_sub_halo_id_added_velocity_all_BHs_tag_max_lum'%(redshift))

    half=hf_half.get('half_by_bhmass')[:]
    tag=hf_tag.get('central_satellite_tag')[:]
    host_halo_id=hf.get('host_halo_id')[:]    
    halo_mass=hf.get('mass')[:]
    boxsize=hf.get('box_size')
    if (run=='MBII'):
        boxsize_in_Kpc=100000.
    else:
        boxsize_in_Kpc=boxsize.value*1000.
    
 
    
    
    get_upper=(half==1)&(tag==1)
    get_lower=(half==-1)&(tag==1)
    
    
    HM_bin,HMF,dHMF=arepo_package.mass_function(halo_mass[get_upper],boxsize_in_Kpc,20,6,9)
    obj.errorbar(HM_bin,HMF,dHMF,color='blue')
    
    HM_bin,HMF,dHMF=arepo_package.mass_function(halo_mass[get_lower],boxsize_in_Kpc,20,6,9)
    obj.errorbar(HM_bin,HMF,dHMF,color='red')
    
    print(len(halo_mass[get_upper]),len(halo_mass[get_lower]))
    print(len(host_halo_id[tag==1]),len(numpy.unique(host_halo_id[tag==1])))
     
    obj.set_xscale('log')
    obj.set_yscale('log')
    i+=1
# Out:
# 13736 12117
# 25853 25853
# 12187 11063
# 23250 23250
# 6053 4377
# 10430 10430
